# %% [markdown]
# ### **Importing Required Libaries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import opendatasets as od

# %% [markdown]
# ### **Downloading Data**

# %%
url="https://www.kaggle.com/datasets/itsmesunil/bank-loan-modelling"
od.download(url)
# Out:
# Skipping, found downloaded files in ".\bank-loan-modelling" (use force=True to force download)

# %% [markdown]
# ### **Importing Data**

# %%
data_description=pd.read_excel("bank-loan-modelling/Bank_Personal_Loan_Modelling.xlsx",sheet_name='Description',header=None)

# %%
data_description.iloc[7:,1:]
# Out:
#                      1                                                  2
# 7                   ID                                        Customer ID
# 8                  Age                  Customer's age in completed years
# 9           Experience                  #years of professional experience
# 10              Income               Annual income of the customer ($000)
# 11             ZIPCode                             Home Address ZIP code.
# 12              Family                        Family size of the customer
# 13               CCAvg     Avg. spending on credit cards per month ($000)
# 14           Education  Education Level. 1: Undergrad; 2: Graduate; 3:...
# 15            Mortgage             Value of house mortgage if any. ($000)
# 16       Personal Loan  Did this customer accept the personal loan off...
# 17  Securities Account  Does the customer have a securities account wi...
# 18          CD Account  Does the customer have a certificate of deposi...
# ...

# %%
df1=pd.read_excel("bank-loan-modelling/Bank_Personal_Loan_Modelling.xlsx",sheet_name='Data',index_col='ID')

# %%
df1.head(14)
# Out:
#     Age  Experience  Income  ZIP Code  Family  CCAvg  Education  Mortgage  \
# ID
# 1    25           1      49     91107       4    1.6          1         0
# 2    45          19      34     90089       3    1.5          1         0
# 3    39          15      11     94720       1    1.0          1         0
# 4    35           9     100     94112       1    2.7          2         0
# 5    35           8      45     91330       4    1.0          2         0
# 6    37          13      29     92121       4    0.4          2       155
# 7    53          27      72     91711       2    1.5          2         0
# 8    50          24      22     93943       1    0.3          3         0
# 9    35          10      81     90089       3    0.6          2       104
# 10   34           9     180     93023       1    8.9          3         0
# 11   65          39     105     94710       4    2.4          3         0
# 12   29           5      45     90277       3    0.1          2         0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 1 to 5000
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 5000 non-null   int64
#  1   Experience          5000 non-null   int64
#  2   Income              5000 non-null   int64
#  3   ZIP Code            5000 non-null   int64
#  4   Family              5000 non-null   int64
#  5   CCAvg               5000 non-null   float64
#  6   Education           5000 non-null   int64
#  7   Mortgage            5000 non-null   int64
#  8   Personal Loan       5000 non-null   int64
#  9   Securities Account  5000 non-null   int64
#  10  CD Account          5000 non-null   int64
#  11  Online              5000 non-null   int64
#  12  CreditCard          5000 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 546.9 KB

# %%
df1.describe()
# Out:
#                Age   Experience       Income      ZIP Code       Family  \
# count  5000.000000  5000.000000  5000.000000   5000.000000  5000.000000
# mean     45.338400    20.104600    73.774200  93152.503000     2.396400
# std      11.463166    11.467954    46.033729   2121.852197     1.147663
# min      23.000000    -3.000000     8.000000   9307.000000     1.000000
# 25%      35.000000    10.000000    39.000000  91911.000000     1.000000
# 50%      45.000000    20.000000    64.000000  93437.000000     2.000000
# 75%      55.000000    30.000000    98.000000  94608.000000     3.000000
# max      67.000000    43.000000   224.000000  96651.000000     4.000000
#
#              CCAvg    Education     Mortgage  Personal Loan  \
# count  5000.000000  5000.000000  5000.000000    5000.000000
# mean      1.937913     1.881000    56.498800       0.096000
# std       1.747666     0.839869   101.713802       0.294621
# min       0.000000     1.000000     0.000000       0.000000
# ...

# %%
df1.isna().sum()
# Out:
# Age                   0
# Experience            0
# Income                0
# ZIP Code              0
# Family                0
# CCAvg                 0
# Education             0
# Mortgage              0
# Personal Loan         0
# Securities Account    0
# CD Account            0
# Online                0
# CreditCard            0
# dtype: int64

# %%
df1['Personal Loan'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df1[['Personal Loan']].groupby(by=df1['Personal Loan']).count()
# Out:
#                Personal Loan
# Personal Loan
# 0                       4520
# 1                        480

# %%
px.bar(df1, x=df1['Personal Loan'].value_counts().index, y=df1['Personal Loan'].value_counts().values, labels={'x':'Value', 'y':'Count'})

# %%
df1.Age.min()
# Out:
# 23

# %%
df1.Age.max()
# Out:
# 67

# %%
px.histogram(df1['Age'],nbins=50)

# %%
df1['Experience'].max()
# Out:
# 43

# %%
df1['Experience'].min()
# Out:
# -3

# %%
df1[(df1['Experience']<0) & (df1['Personal Loan']==0)].shape
# Out:
# (52, 13)

# %% [markdown]
# We can see many rows have problem in data may be wrong data is inserted. <br>
# If we check how many wrong data points have 1 that is they took personal loan during last campaign we will get 0 . that means these datapoints are not good for our model building.

# %%
df2=df1[(df1['Experience']>=0)]

# %%
df2.shape
# Out:
# (4948, 13)

# %%
px.histogram(df2['Experience'])

# %%
df2['Income'].min()
# Out:
# 8

# %%
df2['Income'].max()
# Out:
# 224

# %%
px.histogram(df2['Income'])

# %%
df2['Family'].min()
# Out:
# 1

# %%
df2['Family'].max()
# Out:
# 4

# %%
px.histogram(df2['Family'])

# %%
df2.columns
# Out:
# Index(['Age', 'Experience', 'Income', 'ZIP Code', 'Family', 'CCAvg',
#        'Education', 'Mortgage', 'Personal Loan', 'Securities Account',
#        'CD Account', 'Online', 'CreditCard'],
#       dtype='object')

# %%
df2[(df2['Personal Loan']==1) & (df2['CreditCard']==0)]
# Out:
#       Age  Experience  Income  ZIP Code  Family  CCAvg  Education  Mortgage  \
# ID
# 10     34           9     180     93023       1    8.9          3         0
# 17     38          14     130     95010       4    4.7          3       134
# 19     46          21     193     91604       2    8.1          3         0
# 39     42          18     141     94114       3    5.0          3         0
# 43     32           7     132     90019       4    1.1          2       412
# ...   ...         ...     ...       ...     ...    ...        ...       ...
# 4843   49          23     174     95449       3    4.6          2       590
# 4847   35          10     135     94596       3    4.8          2         0
# 4860   34           8     165     91107       1    7.0          3       541
# 4877   44          19     142     95054       1    1.5          3         0
# 4942   28           4     112     90049       2    1.6          2         0
#
# ...

# %%
df2['CCAvg'].max()
# Out:
# 10.0

# %%
df2['CCAvg'].min()
# Out:
# 0.0

# %%
px.histogram(df2['CCAvg'])

# %%
df2['Education'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
px.histogram(df2['Education'])

# %%
df2['Mortgage'].min()
# Out:
# 0

# %%
df2['Mortgage'].max()
# Out:
# 635

# %%
df2['Securities Account'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2['Securities Account'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2['CD Account'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df2['Online'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df2['CreditCard'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df2.columns.to_list()
# Out:
# ['Age',
#  'Experience',
#  'Income',
#  'ZIP Code',
#  'Family',
#  'CCAvg',
#  'Education',
#  'Mortgage',
#  'Personal Loan',
#  'Securities Account',
#  'CD Account',
#  'Online',
#  'CreditCard']

# %% [markdown]
# ### Splitting data for Training and Testing.

# %%
X=df2[['Age',
 'Experience',
 'Income',
 'Family',
 'CCAvg',
 'Education',
 'Mortgage',
 'Securities Account',
 'CD Account',
 'Online',
 'CreditCard']]

y=df2['Personal Loan']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ### Model

# %%
from sklearn.tree import DecisionTreeClassifier
Tree_Model=DecisionTreeClassifier()

# %%
Tree_Model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=Tree_Model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9848484848484849

# %%
from sklearn.ensemble  import RandomForestClassifier
Rf_Classifier=RandomForestClassifier(n_estimators=20)

# %%
Rf_Classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_test1=Rf_Classifier.predict(X_test)

# %%
accuracy_score(y_test,y_test1)
# Out:
# 0.9838383838383838
